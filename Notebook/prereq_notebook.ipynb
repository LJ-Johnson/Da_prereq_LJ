# %%
print ("Hello world! I'm LJ")
# Out:
# Hello world! I'm LJ

# %% [markdown]
# Hello, my name is Lewis but I go by LJ
# I have three cats Ziggy , Roxy ,and Poato.
# I'm going through this program with my fiance Davy
# I'm excited to get into coding amd will do the best I can.
